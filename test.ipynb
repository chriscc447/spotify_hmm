# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import spotipy.util as util
import pprint
from tqdm.notebook import tqdm
import re
from dateutil.parser import isoparse as dateparse
from datetime import datetime, timedelta
import pickle

pp = pprint.PrettyPrinter(indent=4)

# %%
token_path = "ref/api.txt"
redirect_uri = "http://localhost:8000"

# %%
with open(token_path, "r") as f:
    username, client_id, client_secret = [x.strip() for x in f]

scope = "user-read-recently-played playlist-modify-private user-library-read user-top-read user-library-modify user-modify-playback-state streaming"
token = util.prompt_for_user_token(username,scope,client_id,client_secret,redirect_uri)
sp = spotipy.Spotify(auth=token)

# %%
recent = sp.current_user_recently_played()['items']

# %%
len(recent)
# Out:
# 50

# %%
recent[0]['context']['uri']
# Out:
# 'spotify:playlist:37i9dQZF1E38qXv4KIOTff'

# %%
with open('ref/playlists.data', 'rb') as f:
    pl_uris = pickle.load(f)

# %%
r = list(filter(lambda x: x['context']['uri'] in pl_uris, recent))

# %%
len(r)
# Out:
# 49

# %%
class RecentScraper():
    def __init__(self, redirect_uri = "http://localhost:8000", token_path = "ref/api.txt", recent_path = "data/recent.csv", playlist_path = 'ref/playlists.data', timestamp_path = "data/timestamp.data", all_path = "data/all_songs.csv"):
        #load credentials
        with open(token_path, "r") as f:
            self.username, self.client_id, self.client_secret = [x.strip() for x in f]
        
        #load Spotify client
        scope = "user-read-recently-played playlist-modify-private user-library-read user-top-read user-library-modify user-modify-playback-state streaming"
        token = util.prompt_for_user_token(self.username,scope,self.client_id,self.client_secret,redirect_uri)
        self.sp = spotipy.Spotify(auth=token)
        
        #load playlist uris: only save songs that are from these playlists
        with open(playlist_path, 'rb') as f:
            self.playlist_uris = pickle.load(f)
        
        #load csv file with recent songs
        self.recent_path = recent_path
        self.recent = pd.read_csv(recent_path)
        
        #load last timestamp
        self.timestamp_path = timestamp_path
        with open(timestamp_path, 'rb') as f:
            self.timestamp = pickle.load(f)
        
        #load csv file with all songs in playlists
        self.all_path = all_path
        self.all_songs = pd.read_csv(all_path)
        
    def _get_track_info(self, track_dict):
        """
        given dict of info for single track, returns track artist, track name, when track last played, track uri
        """
        track = track_dict['track']

        name = track['name']
        artist = track['artists'][0]['name']
        uri = track['uri']
        time = datetime.fromisoformat(track_dict['played_at'].replace("T", " ").replace("Z", "")) - timedelta(hours = 4)

        return artist, name, time, uri
        
    def scrape(self, n = 50, save = False):
        
        #load n songs played after last timestamp
        recent = self.sp.current_user_recently_played(limit = n, after = self.timestamp)['items']
        recent = list(filter(lambda x: x['context']['uri'] in self.playlist_uris, recent))        
        #date format
        fmt = "(%m/%d) %H:%M %p"
        
        n_songs = len(recent)
        
        #only run if at least 1 song has been played after last timestamp
        if n_songs != 0:
            bar = tqdm(total = n_songs)

            cols = ['artist', 'title', 'played_at', 'session', 'uri']
            row_skel = {c:None for c in cols}
            data = []      #list of dicts of audio features
            ref = dict()   #query:index in data
            period = timedelta(minutes = 20)

            #process first song
            row = row_skel.copy()
            artist, name, time, uri = self._get_track_info(recent[0])
            str_time = time.strftime(fmt)
                
            most_recent = int(datetime.timestamp(time)*1000)


            row['artist'] = artist
            row['title'] = name
            row['played_at'] = str_time
            row['session'] = hash(str_time)
            row['uri'] = uri

            prev_time = time
            prev_session = row['session']

            data.append(row)
            ref[uri] = len(data)-1
            
            bar.update(1)


            #process rest of songs
            for track in recent[1:]:
                artist, name, time, uri = self._get_track_info(track)
                str_time = time.strftime(fmt)

                if uri not in ref:
                    row = row_skel.copy()
                    row['artist'] = artist
                    row['title'] = name            
                    row['played_at'] = str_time
                    row['uri'] = uri

                    if abs(time - prev_time) > period:
                        prev_session = hash(str_time)
                    row['session'] = prev_session

                    data.append(row)
                    ref[uri] = len(data)-1

                else:
                    row = data[ref[uri]].copy()
                    row['played_at'] = str_time
                    if abs(time - prev_time) > period:
                        prev_session = hash(str_time)
                    row['session'] = prev_session
                    data.append(row) 
                    
                prev_time = time
                bar.update(1)
            bar.close()

            df = pd.DataFrame(data, columns = cols)
            
            
            self.data = data
            self.ref = ref
            self.most_recent = most_recent
            print(f"Songs processed: {n_songs}")
            print(f"Last session time: {datetime.fromtimestamp(most_recent/1000).strftime('%m-%d %H:%M %p')}")
            if save:
                df.append(self.recent).to_csv(self.recent_path, index = False)
                with open(self.timestamp_path, 'wb') as f:
                    pickle.dump(most_recent, f)
                print(f"Session data saved to {self.recent_path}")
                print(f"Last session time saved to {self.timestamp_path}")

            return df
        
        else:
            print(f"No new songs played since {datetime.fromtimestamp(most_recent/1000).strftime('%m-%d %H:%M %p')}")
            return None

# %%
rs = RecentScraper()
rs.scrape(save = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# 50 processed
#                  artist                                      title  \
# 0          Social House                               Love Me Back
# 1                John K                                         OT
# 2         Jeremy Zucker                               Flying Kites
# 3                  LANY                              Malibu Nights
# 4                  joan                                      tokyo
# 5           khai dreams                        Through and Through
# 6                   UMI                                Remember Me
# 7          Clueless Kit                Come to a Stop (feat. Kora)
# 8                  Joji                   SLOW DANCING IN THE DARK
# 9          Chris Wright                                Sleep Alone
# 10            Oh Wonder                                      Plans
# 11              Nightly                                 the movies
# 12         Brent Faiyaz                              Gang Over Luv
# 13                 RINI                                   Carefree
# 14                 LANY             I Don't Wanna Love You Anymore
# 15            Timeflies                         Nobody Has to Know
# 16             Bren Joy                                     Pocket
# 17                 COIN                                Malibu 1992
# 18            Oh Wonder                                      Drive
# 19  Death Cab for Cutie                            Northern Lights
# 20            Cash Cash            Take Me Home (feat. Bebe Rexha)
# 21           flora cash                               Missing Home
# 22     Phillip Phillips                           Gone, Gone, Gone
# 23            Timeflies                                    Gravity
# 24                 LANY                                      ILYSB
# 25          khai dreams                     Summer Is Like a Dream
# 26                 flor                                 back again
# 27                 LANY                              Malibu Nights
# 28              SLANDER                                    Potions
# 29        lovelytheband                                  coachella
# 30               ayokay                                   Cassette
# 31          Post Malone                               I'm Gonna Be
# 32         Delaney Jane                                  Throwback
# 33        lovelytheband                            stupid mistakes
# 34        Marc E. Bassy                               Just My Luck
# 35        lovelytheband                   broken - Cash Cash Remix
# 36           Bryce Vine                             Drew Barrymore
# 37         Boy In Space                                       Cold
# 38              TWIN XL                                       Good
# 39                 Lauv                         Mean It - stripped
# 40                 Lauv                         Mean It - stripped
# 41          Loud Luxury       I'm Not Alright - Frank Walker Remix
# 42              Nightly                           Twenty Something
# 43                 joan                            drive all night
# 44           Bryce Vine                               San Junipero
# 45          Post Malone                                     Myself
# 46             ILLENIUM  Good Things Fall Apart (with Jon Bellion)
# 47              TWIN XL          Don't Wake Me, I'm Still Dreaming
# 48                 Kygo                                  I'll Wait
# 49                keshi                                     2 soon
#
#            played_at              session  \
# 0   (05/12) 17:11 PM -4273624413543488747
# 1   (05/12) 17:07 PM -4273624413543488747
# 2   (05/12) 17:04 PM -4273624413543488747
# 3   (05/12) 17:01 PM -4273624413543488747
# 4   (05/12) 16:54 PM -4273624413543488747
# 5   (05/12) 16:50 PM -4273624413543488747
# 6   (05/12) 16:48 PM -4273624413543488747
# 7   (05/12) 16:45 PM -4273624413543488747
# 8   (05/12) 16:41 PM -4273624413543488747
# 9   (05/12) 16:38 PM -4273624413543488747
# 10  (05/12) 16:35 PM -4273624413543488747
# 11  (05/12) 16:31 PM -4273624413543488747
# 12  (05/12) 16:24 PM -4273624413543488747
# 13  (05/12) 16:20 PM -4273624413543488747
# 14  (05/12) 16:17 PM -4273624413543488747
# 15  (05/12) 16:13 PM -4273624413543488747
# 16  (05/12) 16:10 PM -4273624413543488747
# 17  (05/12) 16:06 PM -4273624413543488747
# 18  (05/12) 16:00 PM -4273624413543488747
# 19  (05/12) 15:57 PM -4273624413543488747
# 20  (05/12) 15:53 PM -4273624413543488747
# 21  (05/12) 15:49 PM -4273624413543488747
# 22  (05/12) 15:46 PM -4273624413543488747
# 23  (05/12) 15:42 PM -4273624413543488747
# 24  (05/12) 15:39 PM -4273624413543488747
# 25  (05/12) 15:35 PM -4273624413543488747
# 26  (05/12) 15:33 PM -4273624413543488747
# 27  (05/12) 15:29 PM -4273624413543488747
# 28  (05/12) 15:25 PM -4273624413543488747
# 29  (05/12) 15:21 PM -4273624413543488747
# 30  (05/11) 23:24 PM  1746310306901120230
# 31  (05/11) 23:21 PM  1746310306901120230
# 32  (05/11) 23:18 PM  1746310306901120230
# 33  (05/11) 23:14 PM  1746310306901120230
# 34  (05/11) 23:10 PM  1746310306901120230
# 35  (05/11) 23:07 PM  1746310306901120230
# 36  (05/11) 23:04 PM  1746310306901120230
# 37  (05/11) 23:00 PM  1746310306901120230
# 38  (05/11) 22:57 PM  1746310306901120230
# 39  (05/11) 22:54 PM  1746310306901120230
# 40  (05/11) 21:29 PM -7771283800123576688
# 41  (05/11) 21:27 PM -7771283800123576688
# 42  (05/11) 21:24 PM -7771283800123576688
# 43  (05/11) 21:19 PM -7771283800123576688
# 44  (05/11) 21:16 PM -7771283800123576688
# 45  (05/11) 21:13 PM -7771283800123576688
# 46  (05/11) 21:10 PM -7771283800123576688
# 47  (05/11) 21:07 PM -7771283800123576688
# 48  (05/11) 21:03 PM -7771283800123576688
# 49  (05/11) 21:00 PM -7771283800123576688
#
#                                      uri
# 0   spotify:track:0Vs8BRdNnyuk0QXWPWvICK
# 1   spotify:track:1YuIEfhp8umr6QSal4FTK4
# 2   spotify:track:0yjdEwkPYbhCXN6uCedpVu
# 3   spotify:track:0Eqg0CQ7bK3RQIMPw1A7pl
# 4   spotify:track:2k7GyFSbErjCvk1QlTChxL
# 5   spotify:track:4RHyIzFRht2z17XeHB9dsF
# 6   spotify:track:630Ug0XtmhhFvAKo0PNuEI
# 7   spotify:track:169koB619bHoCZGLgAcDSX
# 8   spotify:track:0rKtyWc8bvkriBthvHKY8d
# 9   spotify:track:3uLeFt6TLThy8ij5cf6MTt
# 10  spotify:track:5jOQ5v49S1h496AiNlk682
# 11  spotify:track:4RR9tI04ScTvVBCVTyTzhy
# 12  spotify:track:7LaI3mRTJu66r9HKdv7iBx
# 13  spotify:track:1dlgxW5PwUT0v1xzHTCRgH
# 14  spotify:track:7ArrTJ1LwcGAlEO65LUQ7i
# 15  spotify:track:4iaPzRl9XegHsNdZfuHWFD
# 16  spotify:track:58sk9eLrezl40SvzmJKOBG
# 17  spotify:track:0nMqu5vN44GNv8UOQxmBJK
# 18  spotify:track:2kJqNHHGOzLNahukdvlDWN
# 19  spotify:track:28QF5ELXqDnaBjPjGTlzAK
# 20  spotify:track:2zMXH5k5NZy1Nw460bLvRh
# 21  spotify:track:29j2Y1N3vpyvm385G4TFSS
# 22  spotify:track:5L79aNYCTKiZq7vaOElXYj
# 23  spotify:track:4eCe46kZbdcdHeWhjZww8I
# 24  spotify:track:2btKtacOXuMtC9WjcNRvAA
# 25  spotify:track:2X5k8OYH8ibJSZzxAMYVkw
# 26  spotify:track:1J5rHMEvQFpM07iLULi48A
# 27  spotify:track:0Eqg0CQ7bK3RQIMPw1A7pl
# 28  spotify:track:5uGCoNepb3NfYHzdVDXQtC
# 29  spotify:track:1bPJ6Ay1La8IYPCuCvQA7k
# 30  spotify:track:3GweDldi2HrraUKLexWUeb
# 31  spotify:track:1ckLp8lCl8LipXI0ypX72m
# 32  spotify:track:0O64j1yLdHg17XDfleKiYH
# 33  spotify:track:3yGZzSxHvvQKwMsAtFfNF5
# 34  spotify:track:2QsBAfiNmngcrZsOTznqBG
# 35  spotify:track:5W0vgRE9B23TZDj5B7pRUO
# 36  spotify:track:7nvIPwXKGhqtRhssxM99kJ
# 37  spotify:track:5jYe1mOKg5zUx0enf1DOdz
# 38  spotify:track:7sRdxkgNb3m3Ciai38ANmd
# 39  spotify:track:27as7exfxU3cNaYKr3HlHI
# 40  spotify:track:27as7exfxU3cNaYKr3HlHI
# 41  spotify:track:7ojmU04SuSKtIjzODRFIiB
# 42  spotify:track:6Wz9rIfo9tOBcVCd1Mo7F7
# 43  spotify:track:75ZKw8JLaFsYr51J44fQ4N
# 44  spotify:track:2Z8WXN2oV5dzxTWjscQQr2
# 45  spotify:track:2cvOfKHOHgwQlLiuLKP2xR
# 46  spotify:track:3LxG9HkMMFP0MZuiw3O2rF
# 47  spotify:track:6NdL165hAxSKNnozIA2HDY
# 48  spotify:track:6Q3K9gVUZRMZqZKrXovbM2
# 49  spotify:track:5SlU0Yhi51jobhEiGE4xDv
