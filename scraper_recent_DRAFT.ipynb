# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import spotipy.util as util
from tqdm.notebook import tqdm
from dateutil.parser import isoparse as dateparse
from datetime import datetime, timedelta
import pickle
from cluster_classifier import predict
import hashlib
import numpy as np

# %%
class RecentScraper():
    def __init__(self, redirect_uri = "http://localhost:8000", token_path = "ref/api.txt", recent_backup_path = "data/recent_backup.csv", recent_path = "data/recent.csv", playlist_path = 'ref/playlists.data', last_session_path = "data/last_session.data", all_path = "data/all_songs_clustered.csv"):
        #load credentials
        with open(token_path, "r") as f:
            self.username, self.client_id, self.client_secret = [x.strip() for x in f]
        
        #load Spotify client
        scope = "user-read-recently-played playlist-modify-private user-library-read user-top-read user-library-modify user-modify-playback-state streaming"
        token = util.prompt_for_user_token(self.username,scope,self.client_id,self.client_secret,redirect_uri)
        self.sp = spotipy.Spotify(auth=token)
        
        #load playlist uris: only save songs that are from these playlists
        with open(playlist_path, 'rb') as f:
            self.playlist_uris = pickle.load(f)
        
        self.recent_path = recent_path
        self.recent = pd.read_csv(recent_path)
        self.recent_backup_path = recent_backup_path
        
        self.last_session_path = last_session_path
        with open(last_session_path, 'rb') as f:
            data = pickle.load(f)
            self.last_timestamp = int(data['timestamp'])
            self.last_session = data['session']
            
        self.all_path = all_path
        self.all_songs = pd.read_csv(all_path, index_col =  'uri')
        self.audio_features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness','liveness', 'valence', 'tempo']
        
    def _get_track_info(self, track_dict):
        """
        given Spotify's JSON payload with song's audio features, returns dict
        with song features and whether or not song is new (already in all_songs)
            if new, then retrieves audio features and predicts label
            if not, then copies over audio features + label
        """
        track = track_dict['track']
        
        song_data = dict()

        song_data['artist'] = track['artists'][0]['name']
        song_data['title'] = track['name']
        song_data['played_at'] = datetime.fromisoformat(track_dict['played_at'].replace("T", " ").replace("Z", "")) - timedelta(hours = 4)
        uri = track['uri']
        song_data['uri'] = uri
        
        #true if song already in all_songs df
        new = uri not in self.all_songs.index
        
        #if new, retrieve audio features from API and predict label
        if new:
            af = {k:v for (k,v) in self.sp.audio_features(uri)[0].items() if k in self.audio_features}
            label = predict(list(af.values()))
            
        #if not, then copy over audio features + label
        else:
            row = self.all_songs.loc[uri, :]
            af = dict(row[self.audio_features])
            label = row['label']
        

        #add audio features and label to song_data dictionary
        song_data.update(af)
        song_data['label'] = label

        return song_data, new
        
    def scrape(self, n = 50, save = False):

        #filter out songs not played from specified playlists
        raw_recent = self.sp.current_user_recently_played(limit = n, after = self.last_timestamp)['items'][::-1]
        recent = list(filter(lambda x: x['context']['uri'] in self.playlist_uris, raw_recent))
            
        if len(raw_recent) != 0 and len(recent) == 0:
            most_recent = int(datetime.timestamp(datetime.now())*1000)
            print(f"Last session time: {datetime.fromtimestamp(most_recent/1000).strftime('%m-%d %H:%M %p')}")
            print(f"{raw_recent} songs from untracked playlists played")
            with open(self.timestamp_path, 'wb') as f:
                pickle.dump(most_recent, f)
            print(f"Last session time saved to {self.timestamp_path}")
            return
        
        #datetime format
        fmt = "(%m/%d) %H:%M %p"
        n_songs = len(recent)
        
        #load
#         last_session_time = datetime.utcfromtimestamp(self.last_timestamp/1000)
#         prev_time = last_session_time
        prev_time = datetime.utcfromtimestamp(self.last_timestamp/1000)
        
        #if n_songs == 0, then no untracked recent songs
        if n_songs != 0:
            #load previous session id in case new songs played < 20 min after last scrape
            prev_session = self.last_session
            
            #list of dicts of song features
            data = []      
            
            #songs played > 20  min apart are considered separate sessions
            period = timedelta(minutes = 20)
            
            new_songs = []
                
            for track in tqdm(recent):
                row, new = self._get_track_info(track)
                
                if new:
                    #add to list of new songs
                    new_songs.append(f"{row['artist']}: {row['title']}")
                    
                    #update all_songs
                    
                    row_copy = {k:[v] for (k,v) in row.items() if k != 'played_at'}
                    row_copy.update({'pc1':np.nan, 'pc2':np.nan})
                    new_song_df = pd.DataFrame(row_copy, columns = ['uri'] + list(self.all_songs.columns)).set_index('uri')
                    self.all_songs = self.all_songs.append(new_song_df)
                    
                #need time as datetimeobj to check time between songs
                time = row['played_at']
                
                #convert time to specified format for readability in recent df
                str_time = time.strftime(fmt)    
                row['played_at'] = str_time
                  
                #check if elapsed time between this song and previous song > 20 min
                if abs(time - prev_time) > period:
                    #update session id
                    prev_session = hashlib.sha1(str_time.encode('utf-8')).hexdigest()
                    
                row['session'] = prev_session
                
                #update most recent time
                prev_time = time

                data.append(row)

            df = pd.DataFrame(data, columns = self.recent.columns)
            self.data = data
            

            print(f"Songs processed: {n_songs}")
            if len(new_songs) > 0:
                print(f"New songs added to all_songs DataFrame: {new_songs}")
            print(f"Last session time: {prev_time.strftime(fmt)}")
            
            #unix timestamp of last play time
            self.most_recent_timestamp = int(datetime.timestamp(prev_time)*1000)
            
            if save:
                self.recent.to_csv(self.recent_backup_path, index = False) #store old data in backup csv
                self.recent.append(df).to_csv(self.recent_path, index = False) #update old data in recent csv
                with open(self.last_session_path, 'wb') as f:
                    d = {'timestamp': self.most_recent_timestamp, 'session':prev_session}
                    pickle.dump(d, f)
                print(f"Session data saved to {self.recent_path}")
                print(f"Last session time saved to {self.last_session_path}")

            return df
        
        else:
            print(f"No new songs played since {(prev_time-timedelta(hours = 4)).strftime(fmt)}")
            return None

# %%
rs = RecentScraper()
rs.scrape(save = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=16.0), HTML(value='')))
# Songs processed: 16
# Last session time: (05/26) 19:23 PM
# Session data saved to data/recent.csv
# Last session time saved to data/last_session.data
#               artist                              title         played_at  \
# 0      Marc E. Bassy                       Just My Luck  (05/26) 18:32 PM
# 1       Boy In Space                                7UP  (05/26) 18:36 PM
# 2         Mike Perry                         Lighthouse  (05/26) 18:38 PM
# 3            TWIN XL                               Good  (05/26) 18:41 PM
# 4        Post Malone                       I'm Gonna Be  (05/26) 18:44 PM
# 5               joan                    drive all night  (05/26) 18:47 PM
# 6       Said the Sky                           Erase Me  (05/26) 18:51 PM
# 7   Lost Frequencies       Are You With Me - Radio Edit  (05/26) 18:53 PM
# 8           Galantis                    Runaway (U & I)  (05/26) 18:57 PM
# 9       Said the Sky                          All I Got  (05/26) 19:02 PM
# 10           TWIN XL                        Neon Summer  (05/26) 19:06 PM
# 11     lovelytheband                    stupid mistakes  (05/26) 19:10 PM
# 12              Lauv                   Tattoos Together  (05/26) 19:13 PM
# 13   Felix Palmqvist            Think Of Me (feat. Loé)  (05/26) 19:16 PM
# 14     lovelytheband                          coachella  (05/26) 19:20 PM
# 15           TWIN XL  Don't Wake Me, I'm Still Dreaming  (05/26) 19:23 PM
#
#                                      session  \
# 0   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 1   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 2   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 3   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 4   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 5   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 6   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 7   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 8   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 9   4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 10  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 11  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 12  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 13  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 14  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 15  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
#
#                                      uri  danceability  energy  loudness  \
# 0   spotify:track:2QsBAfiNmngcrZsOTznqBG         0.617   0.640    -5.601
# 1   spotify:track:4cB00WOFuQFLoDpnydcx8c         0.616   0.469    -7.380
# 2   spotify:track:4AM3fxgUBkEUO6xScrmB9a         0.543   0.875    -3.033
# 3   spotify:track:7sRdxkgNb3m3Ciai38ANmd         0.617   0.964    -3.559
# 4   spotify:track:1ckLp8lCl8LipXI0ypX72m         0.746   0.559    -4.008
# 5   spotify:track:75ZKw8JLaFsYr51J44fQ4N         0.542   0.758    -5.032
# 6   spotify:track:0AISJtBDtZXgB2fuvcjQEN         0.528   0.610    -6.564
# 7   spotify:track:62nhuooamoroYpJyqE0nLd         0.763   0.610    -8.094
# 8   spotify:track:46lFttIf5hnUZMGvjK0Wxo         0.506   0.805    -4.119
# 9   spotify:track:1iaTDu4PCIWQQOwwwqq5qW         0.325   0.578    -6.786
# 10  spotify:track:4NjW9Srshx2xuTdEoUnf9C         0.398   0.785    -4.853
# 11  spotify:track:3yGZzSxHvvQKwMsAtFfNF5         0.697   0.713    -6.567
# 12  spotify:track:1Srt81FTalOhRw7t7l8Yh8         0.862   0.400    -7.486
# 13  spotify:track:5uRjHOMFT16RS1f8ZNlkzm         0.499   0.610    -4.480
# 14  spotify:track:1bPJ6Ay1La8IYPCuCvQA7k         0.563   0.646    -6.849
# 15  spotify:track:6NdL165hAxSKNnozIA2HDY         0.388   0.777    -5.194
#
#     speechiness  acousticness  liveness  valence    tempo  label
# 0        0.0420      0.283000    0.1640    0.346  156.980      4
# 1        0.0270      0.016700    0.1110    0.233  135.035      4
# 2        0.0320      0.079500    0.0610    0.244  154.936      3
# 3        0.0355      0.113000    0.2470    0.961   75.978      0
# 4        0.0316      0.703000    0.1480    0.368  117.943      2
# 5        0.0313      0.000184    0.1440    0.430  156.128      3
# 6        0.0287      0.376000    0.2110    0.304  130.110      6
# 7        0.0355      0.275000    0.1200    0.392  121.031      4
# 8        0.0469      0.007110    0.0856    0.383  126.008      3
# 9        0.0455      0.158000    0.5750    0.103  144.745      3
# 10       0.0424      0.001290    0.1090    0.688   75.023      0
# 11       0.0265      0.133000    0.2300    0.529  128.974      4
# 12       0.0736      0.005750    0.1230    0.596  122.963      2
# 13       0.0310      0.606000    0.0693    0.299  155.212      6
# 14       0.0312      0.066400    0.0877    0.288  115.013      4
# 15       0.0341      0.021800    0.1010    0.218  163.805      3

# %%
df = pd.read_csv("data/recent.csv")
df.tail(20)
# Out:
#                artist                              title         played_at  \
# 335            Khalid                                OTW  (05/25) 20:12 PM
# 336      Boy In Space                                7UP  (05/26) 08:32 AM
# 337        Kid Travis                   Strawberry Skies  (05/26) 12:36 PM
# 338          Bren Joy              Henny in the Hamptons  (05/26) 13:04 PM
# 339     Marc E. Bassy                       Just My Luck  (05/26) 18:32 PM
# 340      Boy In Space                                7UP  (05/26) 18:36 PM
# 341        Mike Perry                         Lighthouse  (05/26) 18:38 PM
# 342           TWIN XL                               Good  (05/26) 18:41 PM
# 343       Post Malone                       I'm Gonna Be  (05/26) 18:44 PM
# 344              joan                    drive all night  (05/26) 18:47 PM
# 345      Said the Sky                           Erase Me  (05/26) 18:51 PM
# 346  Lost Frequencies       Are You With Me - Radio Edit  (05/26) 18:53 PM
# 347          Galantis                    Runaway (U & I)  (05/26) 18:57 PM
# 348      Said the Sky                          All I Got  (05/26) 19:02 PM
# 349           TWIN XL                        Neon Summer  (05/26) 19:06 PM
# 350     lovelytheband                    stupid mistakes  (05/26) 19:10 PM
# 351              Lauv                   Tattoos Together  (05/26) 19:13 PM
# 352   Felix Palmqvist            Think Of Me (feat. Loé)  (05/26) 19:16 PM
# 353     lovelytheband                          coachella  (05/26) 19:20 PM
# 354           TWIN XL  Don't Wake Me, I'm Still Dreaming  (05/26) 19:23 PM
#
#                                       session  \
# 335  d2a04f014f6d12fcb72e387150666fbddfc3dae5
# 336  b8742d0bf900ad4eb0e5a08a849ee7396363e4b2
# 337  7193ad525a76f77a2b1444efd77b4bbea950d254
# 338  d4d869240c95d67b65c6160411f0a744889d519f
# 339  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 340  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 341  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 342  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 343  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 344  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 345  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 346  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 347  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 348  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 349  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 350  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 351  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 352  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 353  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
# 354  4bd16a1c612ebfe2afb94ee23ac1cea35bb1d015
#
#                                       uri  danceability  energy  loudness  \
# 335  spotify:track:6Hgh47WXVKtXN5zGOu0hjI         0.652   0.678    -6.183
# 336  spotify:track:4cB00WOFuQFLoDpnydcx8c         0.616   0.469    -7.380
# 337  spotify:track:2p1onANhkUkyMZKKigOUJu         0.650   0.462    -6.589
# 338  spotify:track:19NKbRV1zevCIzePp88Wzh         0.631   0.634    -6.786
# 339  spotify:track:2QsBAfiNmngcrZsOTznqBG         0.617   0.640    -5.601
# 340  spotify:track:4cB00WOFuQFLoDpnydcx8c         0.616   0.469    -7.380
# 341  spotify:track:4AM3fxgUBkEUO6xScrmB9a         0.543   0.875    -3.033
# 342  spotify:track:7sRdxkgNb3m3Ciai38ANmd         0.617   0.964    -3.559
# 343  spotify:track:1ckLp8lCl8LipXI0ypX72m         0.746   0.559    -4.008
# 344  spotify:track:75ZKw8JLaFsYr51J44fQ4N         0.542   0.758    -5.032
# 345  spotify:track:0AISJtBDtZXgB2fuvcjQEN         0.528   0.610    -6.564
# 346  spotify:track:62nhuooamoroYpJyqE0nLd         0.763   0.610    -8.094
# 347  spotify:track:46lFttIf5hnUZMGvjK0Wxo         0.506   0.805    -4.119
# 348  spotify:track:1iaTDu4PCIWQQOwwwqq5qW         0.325   0.578    -6.786
# 349  spotify:track:4NjW9Srshx2xuTdEoUnf9C         0.398   0.785    -4.853
# 350  spotify:track:3yGZzSxHvvQKwMsAtFfNF5         0.697   0.713    -6.567
# 351  spotify:track:1Srt81FTalOhRw7t7l8Yh8         0.862   0.400    -7.486
# 352  spotify:track:5uRjHOMFT16RS1f8ZNlkzm         0.499   0.610    -4.480
# 353  spotify:track:1bPJ6Ay1La8IYPCuCvQA7k         0.563   0.646    -6.849
# 354  spotify:track:6NdL165hAxSKNnozIA2HDY         0.388   0.777    -5.194
#
#      speechiness  acousticness  liveness  valence    tempo  label
# 335       0.0541      0.183000    0.1060    0.280   72.989      4
# 336       0.0270      0.016700    0.1110    0.233  135.035      4
# 337       0.0891      0.366000    0.1590    0.650   89.887      2
# 338       0.1150      0.634000    0.1680    0.479   87.903      2
# 339       0.0420      0.283000    0.1640    0.346  156.980      4
# 340       0.0270      0.016700    0.1110    0.233  135.035      4
# 341       0.0320      0.079500    0.0610    0.244  154.936      3
# 342       0.0355      0.113000    0.2470    0.961   75.978      0
# 343       0.0316      0.703000    0.1480    0.368  117.943      2
# 344       0.0313      0.000184    0.1440    0.430  156.128      3
# 345       0.0287      0.376000    0.2110    0.304  130.110      6
# 346       0.0355      0.275000    0.1200    0.392  121.031      4
# 347       0.0469      0.007110    0.0856    0.383  126.008      3
# 348       0.0455      0.158000    0.5750    0.103  144.745      3
# 349       0.0424      0.001290    0.1090    0.688   75.023      0
# 350       0.0265      0.133000    0.2300    0.529  128.974      4
# 351       0.0736      0.005750    0.1230    0.596  122.963      2
# 352       0.0310      0.606000    0.0693    0.299  155.212      6
# 353       0.0312      0.066400    0.0877    0.288  115.013      4
# 354       0.0341      0.021800    0.1010    0.218  163.805      3

# %%
# Out:
#              artist                     title         played_at  \
# 0        Kid Travis          Strawberry Skies  (05/26) 12:36 PM
# 1      Boy In Space                       7UP  (05/26) 08:32 AM
# 2            Khalid                       OTW  (05/25) 20:12 PM
# 3       Post Malone                Rich & Sad  (05/25) 19:59 PM
# 4  The Chainsmokers  Something Just Like This  (05/25) 19:54 PM
#
#                                     session  \
# 0  7193ad525a76f77a2b1444efd77b4bbea950d254
# 1  b8742d0bf900ad4eb0e5a08a849ee7396363e4b2
# 2  d2a04f014f6d12fcb72e387150666fbddfc3dae5
# 3  d2a04f014f6d12fcb72e387150666fbddfc3dae5
# 4  d2a04f014f6d12fcb72e387150666fbddfc3dae5
#
#                                     uri  danceability  energy  loudness  \
# 0  spotify:track:2p1onANhkUkyMZKKigOUJu         0.650   0.462    -6.589
# 1  spotify:track:4cB00WOFuQFLoDpnydcx8c         0.616   0.469    -7.380
# 2  spotify:track:6Hgh47WXVKtXN5zGOu0hjI         0.652   0.678    -6.183
# 3  spotify:track:2VdT56BGpdqNHUgOe1j5vc         0.599   0.571    -4.998
# 4  spotify:track:6RUKPb4LETWmmr3iAEQktW         0.617   0.635    -6.769
#
#    speechiness  acousticness  liveness  valence    tempo  label
# 0       0.0891        0.3660    0.1590    0.650   89.887      2
# 1       0.0270        0.0167    0.1110    0.233  135.035      4
# 2       0.0541        0.1830    0.1060    0.280   72.989      4
# 3       0.0665        0.1980    0.0969    0.285  151.974      4
# 4       0.0317        0.0498    0.1640    0.446  103.019      4

# %%
rs.most_recent_timestamp
# Out:
# 1590496367026

# %%
dfb = pd.read_csv("data/recent_backup.csv")

# %%
dfb.head()
# Out:
#              artist                     title         played_at  \
# 0            Khalid                       OTW  (05/25) 20:12 PM
# 1       Post Malone                Rich & Sad  (05/25) 19:59 PM
# 2            Khalid                       OTW  (05/25) 20:12 PM
# 3       Post Malone                Rich & Sad  (05/25) 19:59 PM
# 4  The Chainsmokers  Something Just Like This  (05/25) 19:54 PM
#
#                                     session  \
# 0  e2d00c9181a17d94bb774e0f19ad79a05cce6c0d
# 1  e2d00c9181a17d94bb774e0f19ad79a05cce6c0d
# 2  d2a04f014f6d12fcb72e387150666fbddfc3dae5
# 3  d2a04f014f6d12fcb72e387150666fbddfc3dae5
# 4  d2a04f014f6d12fcb72e387150666fbddfc3dae5
#
#                                     uri  danceability  energy  loudness  \
# 0  spotify:track:6Hgh47WXVKtXN5zGOu0hjI         0.652   0.678    -6.183
# 1  spotify:track:2VdT56BGpdqNHUgOe1j5vc         0.599   0.571    -4.998
# 2  spotify:track:6Hgh47WXVKtXN5zGOu0hjI         0.652   0.678    -6.183
# 3  spotify:track:2VdT56BGpdqNHUgOe1j5vc         0.599   0.571    -4.998
# 4  spotify:track:6RUKPb4LETWmmr3iAEQktW         0.617   0.635    -6.769
#
#    speechiness  acousticness  liveness  valence    tempo  label
# 0       0.0541        0.1830    0.1060    0.280   72.989      4
# 1       0.0665        0.1980    0.0969    0.285  151.974      4
# 2       0.0541        0.1830    0.1060    0.280   72.989      4
# 3       0.0665        0.1980    0.0969    0.285  151.974      4
# 4       0.0317        0.0498    0.1640    0.446  103.019      4

# %%
df.session[0]
# Out:
# 4.82707e+18

# %%
df.drop_duplicates(['played_at']).reset_index(drop = True).to_csv("data/recent.csv", index = False)

# %%
pd.concat([df.loc[]
# Out:
#                artist                     title         played_at  \
# 0              Khalid                       OTW  (05/25) 20:12 PM
# 1         Post Malone                Rich & Sad  (05/25) 19:59 PM
# 2    The Chainsmokers  Something Just Like This  (05/25) 19:54 PM
# 3              Khalid                       OTW  (05/25) 20:12 PM
# 4         Post Malone                Rich & Sad  (05/25) 19:59 PM
# ..                ...                       ...               ...
# 341            Valley            Swim - Reprise  (05/08) 19:48 PM
# 342       Post Malone              I'm Gonna Be  (05/08) 19:44 PM
# 343     lovelytheband                 coachella  (05/08) 19:41 PM
# 344          88rising            La La Lost You  (05/08) 19:37 PM
# 345             Bazzi                      Mine  (05/08) 19:34 PM
#
#                  session                                   uri danceability  \
# 0    4827071877810892581  spotify:track:6Hgh47WXVKtXN5zGOu0hjI        0.652
# 1    4827071877810892581  spotify:track:2VdT56BGpdqNHUgOe1j5vc        0.599
# 2    4827071877810892581  spotify:track:6RUKPb4LETWmmr3iAEQktW        0.617
# 3    4827071877810892581  spotify:track:6Hgh47WXVKtXN5zGOu0hjI        0.652
# 4    4827071877810892581  spotify:track:2VdT56BGpdqNHUgOe1j5vc        0.599
# ..                   ...                                   ...          ...
# 341 -2878427576433552475  spotify:track:4eVE7ruYH5dNGYKT2jd5So        0.493
# 342 -2878427576433552475  spotify:track:1ckLp8lCl8LipXI0ypX72m        0.746
# 343 -2878427576433552475  spotify:track:1bPJ6Ay1La8IYPCuCvQA7k        0.563
# 344 -2878427576433552475  spotify:track:5Htq8DDDN0Xce9MwqzAzui        0.721
# 345 -2878427576433552475  spotify:track:7uzmGiiJyRfuViKKK3lVmR         0.71
#
#                  energy loudness speechiness acousticness  \
# 0    0.6779999999999999   -6.183      0.0541        0.183
# 1    0.5710000000000001   -4.998      0.0665        0.198
# 2                 0.635   -6.769      0.0317       0.0498
# 3    0.6779999999999999   -6.183      0.0541        0.183
# 4    0.5710000000000001   -4.998      0.0665        0.198
# ..                  ...      ...         ...          ...
# 341               0.782   -6.968      0.0353       0.0187
# 342  0.5589999999999999   -4.008      0.0316        0.703
# 343  0.6459999999999999   -6.849      0.0312       0.0664
# 344  0.5820000000000001   -8.251      0.0411        0.315
# 345               0.789   -3.874      0.0722       0.0161
#
#                 liveness              valence              tempo label
# 0                  0.106                 0.28  72.98899999999998     4
# 1                 0.0969                0.285            151.974     4
# 2    0.16399999999999998                0.446            103.019     4
# 3                  0.106                 0.28  72.98899999999998     4
# 4                 0.0969                0.285            151.974     4
# ..                   ...                  ...                ...   ...
# 341                0.321                0.314            104.941     4
# 342  0.14800000000000002                0.368            117.943     2
# 343               0.0877  0.28800000000000003            115.013     4
# 344                0.065                0.487            100.083     2
# 345                0.451   0.7170000000000001            142.929     0
#
# [346 rows x 14 columns]
